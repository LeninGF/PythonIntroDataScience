# %% [markdown]
# # Capítulo 5
# ## Numpy
#
# - Sirve para operaciones vectoriales

# %%
import numpy as np

np.__version__
# Out:
# '1.26.4'

# %%
x = np.array([1,2,3,4,5])
type(x)
# Out:
# numpy.ndarray

# %%
y = np.array([6,7,8,9,10])
z = x+y
z
# Out:
# array([ 7,  9, 11, 13, 15])

# %%
z = x*y
z
# Out:
# array([ 6, 14, 24, 36, 50])

# %%
x.shape, y.shape, z.shape
# Out:
# ((5,), (5,), (5,))

# %%
A = np.array([[1,2,3], [4,5,6]])
A
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
A.shape
# Out:
# (2, 3)

# %%
B = np.random.randint(0,100,(2,3))
B
# Out:
# array([[95, 24, 30],
#        [44, 72, 96]])

# %%
B.shape
# Out:
# (2, 3)

# %% [markdown]
# ## Matplotlib

# %%
x = np.linspace(-5, 5, 100)
x
# Out:
# array([-5.        , -4.8989899 , -4.7979798 , -4.6969697 , -4.5959596 ,
#        -4.49494949, -4.39393939, -4.29292929, -4.19191919, -4.09090909,
#        -3.98989899, -3.88888889, -3.78787879, -3.68686869, -3.58585859,
#        -3.48484848, -3.38383838, -3.28282828, -3.18181818, -3.08080808,
#        -2.97979798, -2.87878788, -2.77777778, -2.67676768, -2.57575758,
#        -2.47474747, -2.37373737, -2.27272727, -2.17171717, -2.07070707,
#        -1.96969697, -1.86868687, -1.76767677, -1.66666667, -1.56565657,
#        -1.46464646, -1.36363636, -1.26262626, -1.16161616, -1.06060606,
#        -0.95959596, -0.85858586, -0.75757576, -0.65656566, -0.55555556,
#        -0.45454545, -0.35353535, -0.25252525, -0.15151515, -0.05050505,
#         0.05050505,  0.15151515,  0.25252525,  0.35353535,  0.45454545,
#         0.55555556,  0.65656566,  0.75757576,  0.85858586,  0.95959596,
#         1.06060606,  1.16161616,  1.26262626,  1.36363636,  1.46464646,
# ...

# %%
y = x**2
y
# Out:
# array([2.50000000e+01, 2.40001020e+01, 2.30206101e+01, 2.20615243e+01,
#        2.11228446e+01, 2.02045710e+01, 1.93067034e+01, 1.84292419e+01,
#        1.75721865e+01, 1.67355372e+01, 1.59192939e+01, 1.51234568e+01,
#        1.43480257e+01, 1.35930007e+01, 1.28583818e+01, 1.21441690e+01,
#        1.14503622e+01, 1.07769615e+01, 1.01239669e+01, 9.49137843e+00,
#        8.87919600e+00, 8.28741965e+00, 7.71604938e+00, 7.16508520e+00,
#        6.63452709e+00, 6.12437506e+00, 5.63462912e+00, 5.16528926e+00,
#        4.71635547e+00, 4.28782777e+00, 3.87970615e+00, 3.49199061e+00,
#        3.12468115e+00, 2.77777778e+00, 2.45128048e+00, 2.14518927e+00,
#        1.85950413e+00, 1.59422508e+00, 1.34935211e+00, 1.12488522e+00,
#        9.20824406e-01, 7.37169677e-01, 5.73921028e-01, 4.31078461e-01,
#        3.08641975e-01, 2.06611570e-01, 1.24987246e-01, 6.37690032e-02,
#        2.29568411e-02, 2.55076013e-03, 2.55076013e-03, 2.29568411e-02,
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(x,y)
plt.title('La Parabola')
plt.grid()
plt.show()

# %%
plt.scatter(x,y)
plt.show()

# %% [markdown]
# # Capítulo 6
# ## Pandas
#
# Pandas se sla hoja de calculo de python

# %%
import pandas as pd

pd.__version__
# Out:
# '2.2.2'

# %%
persona1  = {'nombre': "Lenin",
             'apellido': "Falconi",
             'edad': 40,
             'email':"lenin.g.falconi@gmail.com"}
persona2  = {'nombre': "Silvana",
             'apellido': "Arevalo",
             'edad': 40,
             'email':"silvanaarevalo18@gmail.com"}
persona3  = {'nombre': "Edith",
             'apellido': "Arevalo",
             'edad': 46,
             'email':"edith.arevalo@gmail.com"}

tthh = [persona1, persona2, persona3]

# %%
df_th = pd.DataFrame(tthh)
df_th
# Out:
#     nombre apellido  edad                       email
# 0    Lenin  Falconi    40   lenin.g.falconi@gmail.com
# 1  Silvana  Arevalo    40  silvanaarevalo18@gmail.com
# 2    Edith  Arevalo    46     edith.arevalo@gmail.com

# %%
type(df_th)
# Out:
# pandas.core.frame.DataFrame

# %%
df_th.shape
# Out:
# (3, 4)

# %%
df_th.columns
# Out:
# Index(['nombre', 'apellido', 'edad', 'email'], dtype='object')

# %%
df_th.describe()
# Out:
#             edad
# count   3.000000
# mean   42.000000
# std     3.464102
# min    40.000000
# 25%    40.000000
# 50%    40.000000
# 75%    43.000000
# max    46.000000

# %%
# personas con edad mayor a la mean

resp = df_th[df_th.edad > df_th.edad.mean()]
resp
# Out:
#   nombre apellido  edad                    email
# 2  Edith  Arevalo    46  edith.arevalo@gmail.com

# %%
path_dataset = "dataset/REPORTE_DESI_LAKENDD2_2024030622000871Primicias.csv"
df = pd.read_csv(path_dataset, 
                 converters={"d_NDD":str, "d_CEDULA_FISCAL":str}, 
                 parse_dates=["f_FECHA_PS", "d_FECHA_US", "d_FECHA_INCIDENTE"])
df.shape
# Out:
# (215469, 45)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215469 entries, 0 to 215468
# Data columns (total 45 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   f_FECHA_PS                  215469 non-null  datetime64[ns]
#  1   d_FECHA_US                  215469 non-null  datetime64[ns]
#  2   d_NDD                       215469 non-null  object
#  3   d_ANIO_PS                   215469 non-null  int64
#  4   d_ANIO_US                   215469 non-null  int64
#  5   d_FECHA_INCIDENTE           215469 non-null  datetime64[ns]
#  6   d_ANIO_INCIDENTE            215469 non-null  int64
#  7   d_MES_PS                    215469 non-null  int64
#  8   d_MES_US                    215469 non-null  int64
#  9   d_MES_INCIDENTE             215469 non-null  int64
#  10  d_ARTICULO                  215469 non-null  int64
#  11  d_ARTICULO_CIRCUNSTANCIAL   215469 non-null  object
# ...

# %%
df.head(10)
# Out:
#   f_FECHA_PS d_FECHA_US            d_NDD  d_ANIO_PS  d_ANIO_US  \
# 0 2024-02-29 2024-02-29  010101824021104       2024       2024
# 1 2024-02-29 2024-02-29  060101824020524       2024       2024
# 2 2024-02-29 2024-02-29  092001824020152       2024       2024
# 3 2024-02-29 2024-02-29  120701824020098       2024       2024
# 4 2024-02-29 2024-02-29  090101824026133       2024       2024
# 5 2024-02-29 2024-02-29  090101824026346       2024       2024
# 6 2024-02-29 2024-02-29  030101824020157       2024       2024
# 7 2024-02-29 2024-02-29  050101824020357       2024       2024
# 8 2024-02-29 2024-02-29  090101824026343       2024       2024
# 9 2024-02-29 2024-02-29  090101824026158       2024       2024
#
#   d_FECHA_INCIDENTE  d_ANIO_INCIDENTE  d_MES_PS  d_MES_US  d_MES_INCIDENTE  \
# 0        2024-02-23              2024         2         2                2
# 1        2024-02-29              2024         2         2                2
# ...

# %%
df.tail(10)
# Out:
#        f_FECHA_PS d_FECHA_US            d_NDD  d_ANIO_PS  d_ANIO_US  \
# 215459 2022-01-01 2022-01-01  100101822010005       2022       2022
# 215460 2022-01-01 2022-01-01  090101822010036       2022       2022
# 215461 2022-01-01 2022-01-01  180101822010007       2022       2022
# 215462 2022-01-01 2022-01-01  170101822010006       2022       2022
# 215463 2022-01-01 2022-01-01  180101822010010       2022       2022
# 215464 2022-01-01 2022-01-01  170101822010010       2022       2022
# 215465 2022-01-01 2022-01-01  170101822010027       2022       2022
# 215466 2022-01-01 2022-01-01  240201822010002       2022       2022
# 215467 2022-01-01 2022-02-16  090101822010040       2022       2022
# 215468 2022-01-01 2022-01-14  090101822010008       2022       2022
#
#        d_FECHA_INCIDENTE  d_ANIO_INCIDENTE  d_MES_PS  d_MES_US  \
# 215459        2021-12-29              2021         1         1
# 215460        2022-01-01              2022         1         1
# ...

# %%
df.sample(5)
# Out:
#        f_FECHA_PS d_FECHA_US            d_NDD  d_ANIO_PS  d_ANIO_US  \
# 210589 2022-01-22 2022-01-22  170101822013561       2022       2022
# 91256  2023-04-12 2023-04-12  091001823040179       2023       2023
# 110026 2023-02-08 2023-02-08  170101823021245       2023       2023
# 209589 2022-01-26 2022-01-26  170101822014227       2022       2022
# 399    2024-02-28 2024-02-28  230101824020804       2024       2024
#
#        d_FECHA_INCIDENTE  d_ANIO_INCIDENTE  d_MES_PS  d_MES_US  \
# 210589        2022-01-22              2022         1         1
# 91256         2023-01-15              2023         4         4
# 110026        2023-02-07              2023         2         2
# 209589        2022-01-20              2022         1         1
# 399           2024-02-02              2024         2         2
#
#         d_MES_INCIDENTE  ...  d_INVOLUCRADO_APREHENDIDO  \
# 210589                1  ...                          0
# 91256                 1  ...                          0
# ...

# %%
idx = 83811

df[["d_NDD", "d_DELITO", "d_DELITO_CIRCUNSTANCIAL", "d_ARTICULO_CIRCUNSTANCIAL"]].iloc[idx]
# Out:
# d_NDD                        090101823051473
# d_DELITO                                ROBO
# d_DELITO_CIRCUNSTANCIAL                 ROBO
# d_ARTICULO_CIRCUNSTANCIAL            (empty)
# Name: 83811, dtype: object

# %%
resp = df[df["d_ARTICULO_CIRCUNSTANCIAL"].str.contains("\n")]
resp.shape
# Out:
# (218, 45)

# %%
resp[["d_NDD", "d_DELITO", "d_DELITO_CIRCUNSTANCIAL", "d_ARTICULO_CIRCUNSTANCIAL"]].head()
# Out:
#                  d_NDD d_DELITO  \
# 83810  090101823051587     ROBO
# 84837  010101823050073     ROBO
# 88079  120501823040490     ROBO
# 88186  240201823040154     ROBO
# 89149  091001823040266     ROBO
#
#                                  d_DELITO_CIRCUNSTANCIAL  \
# 83810  ROBO SI A CONSECUENCIA DEL ROBO SE OCASIONAN L...
# 84837  ROBO SI A CONSECUENCIA DEL ROBO SE OCASIONAN L...
# 88079  ROBO SI A CONSECUENCIA DEL ROBO SE OCASIONAN L...
# 88186  ROBO SI A CONSECUENCIA DEL ROBO SE OCASIONAN L...
# 89149  ROBO SI A CONSECUENCIA DEL ROBO SE OCASIONAN L...
#
#       d_ARTICULO_CIRCUNSTANCIAL
# 83810    189 INC. 4 \n152 NUM 5
# 84837    189 INC. 4 \n152 NUM 5
# 88079    189 INC. 4 \n152 NUM 5
# 88186    189 INC. 4 \n152 NUM 5
# 89149    189 INC. 4 \n152 NUM 5
